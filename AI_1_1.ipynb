# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalAA1/Inspirit-AI-1-1-Stock-Market-ML-Project/blob/main/AI_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
#setup
#code
ticker = yf.Ticker('GS') #import data
aapl_df = ticker.history(period="5y") #get data from 5 year period in dataframe
aapl_df.drop(['High','Close','Volume','Dividends','Stock Splits'], axis=1, inplace=True) #only have two columns, not seven
open = np.empty(shape = (1259), dtype = float)
close = np.empty(shape = (1259), dtype = float)

open=aapl_df[['Open']].to_numpy()

# %%
print(open)
# Out:
# [[269.99641351]
#  [267.45670849]
#  [270.84002379]
#  ...
#  [938.77001953]
#  [934.        ]
#  [947.32000732]]

# %%
X = np.zeros((1260,3))
Y = [0]*1260
for i in range(1250):
 X[i] = [open[i][0],open[i+1][0],open[i+2][0]]
 Y[i] = open[i+3][0]
print(X[0])
print(Y[0])
# Out:
# [269.99641351 267.45670849 270.84002379]
# 262.6882147395456

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.33, random_state=42)

# %% [markdown]
# 4-5

# %%
print(X_train[0])
print(y_train[0])
# Out:
# [300.09528996 299.37664301 296.9809953 ]
# 283.3721236025758

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
linr = linear_model.LinearRegression()
linr.fit(X_train, y_train)
y_pred_linear_regression = linr.predict(X_test)
y_pred_linr_train = linr.predict(X_train)
# The coefficients
print("Coefficients: \n", linr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_linear_regression))
inverse_linr = 1/mean_squared_error(y_test, y_pred_linear_regression)
inverse_linr_train = 1/mean_squared_error(y_train, y_pred_linr_train)
# Out:
# Coefficients:
#  [ 0.0385094  -0.03529991  0.9991405 ]
# Mean squared error: 69.42

# %%
from sklearn.neural_network import MLPRegressor
regr = MLPRegressor(max_iter=2000, tol=1e-4)
regr.fit(X_train, y_train)
y_pred_mlp = regr.predict(X_test)
y_pred_mlp_train = regr.predict(X_train)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_mlp))
inverse_regr = 1/mean_squared_error(y_test, y_pred_mlp)
inverse_regr_train = 1/mean_squared_error(y_train, y_pred_mlp_train)
# Out:
# Mean squared error: 110.91

# %%
from sklearn.neural_network import MLPRegressor # second set of parameters
regr_two = MLPRegressor(max_iter=4000, tol=1e-6)
regr_two.fit(X_train, y_train)
y_pred_mlp_two = regr_two.predict(X_test)
y_pred_mlp_two_train = regr_two.predict(X_train)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_mlp_two))
inverse_regr_two = 1/mean_squared_error(y_test, y_pred_mlp_two)
inverse_regr_two_train = 1/mean_squared_error(y_train, y_pred_mlp_train)
# Out:
# Mean squared error: 89.80

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(max_depth = 7)
regressor.fit(X_train, y_train)
y_pred_decision_tree = regressor.predict(X_test)
y_pred_decision_train = regressor.predict(X_train)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_decision_tree))
inverse_regressor = 1/mean_squared_error(y_test, y_pred_decision_tree)
inverse_regressor_train = 1/(mean_squared_error(y_train, y_pred_decision_train) + 0.0001)
# Out:
# Mean squared error: 105.11

# %%
from sklearn.model_selection import cross_val_score # second set of parameters
from sklearn.tree import DecisionTreeRegressor
regressor_two = DecisionTreeRegressor(max_depth = 10)
regressor_two.fit(X_train, y_train)
y_pred_decision_tree_two = regressor_two.predict(X_test)
y_pred_decision_train_two = regressor_two.predict(X_train)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_decision_tree_two))
inverse_regressor_two = 1/mean_squared_error(y_test, y_pred_decision_tree_two)
inverse_regressor_two_train = 1/(mean_squared_error(y_train, y_pred_decision_train_two) + 0.0001)
# Out:
# Mean squared error: 130.27

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
rand = RandomForestRegressor(max_depth = 10, n_estimators = 10, random_state=0)
rand.fit(X_train, y_train)
y_pred_random_forest = rand.predict(X_test)
y_pred_rand_train = rand.predict(X_train)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_random_forest))
inverse_rand = 1/mean_squared_error(y_test, y_pred_random_forest)
inverse_rand_train = 1/mean_squared_error(y_train, y_pred_rand_train)
# Out:
# Mean squared error: 95.66

# %%
from sklearn.ensemble import RandomForestRegressor # second set of parameters
from sklearn.datasets import make_regression
rand_two = RandomForestRegressor(max_depth = 25, n_estimators = 25, random_state=0)
rand_two.fit(X_train, y_train)
y_pred_random_forest_two = rand_two.predict(X_test)
y_pred_rand_train_two = rand_two.predict(X_train)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_random_forest_two))
inverse_rand_two = 1/mean_squared_error(y_test, y_pred_random_forest_two)
inverse_rand_train_two = 1/mean_squared_error(y_train, y_pred_rand_train_two)
# Out:
# Mean squared error: 101.14

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=2)
neigh.fit(X_train, y_train)
y_pred_neighbors = neigh.predict(X_test)
y_pred_neighbors_train = neigh.predict(X_train)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_neighbors))
inverse_neigh = 1/mean_squared_error(y_test, y_pred_neighbors)
inverse_neigh_train = 1/mean_squared_error(y_train, y_pred_neighbors_train)
# Out:
# Mean squared error: 138.53

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh_two = KNeighborsRegressor(n_neighbors=3)
neigh_two.fit(X_train, y_train)
y_pred_neighbors_two = neigh_two.predict(X_test)
y_pred_neighbors_train_two = neigh_two.predict(X_train)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_neighbors_two))
inverse_neigh_two = 1/mean_squared_error(y_test, y_pred_neighbors_two)
inverse_neigh_train_two = 1/mean_squared_error(y_train, y_pred_neighbors_train_two)
# Out:
# Mean squared error: 131.88

# %%
## build a model to take the average of all these predictions
avg_pred = (linr.predict(X_test) + regr.predict(X_test) + regr_two.predict(X_test) + regressor.predict(X_test) + regressor_two.predict(X_test)+ rand.predict(X_test) + rand_two.predict(X_test) + neigh.predict(X_test)+ neigh_two.predict(X_test)) / 9
print("Mean squared error: %.2f" % mean_squared_error(y_test, avg_pred))
# Out:
# Mean squared error: 91.60

# %%
sum_test = inverse_linr + inverse_regr + inverse_regr_two + inverse_regressor + inverse_regressor_two + inverse_rand + inverse_rand_two + inverse_neigh + inverse_neigh_two
w_linear = inverse_linr/sum_test
print(w_linear)

w_regr = inverse_regr/sum_test
print(w_regr)

w_regr_two = inverse_regr_two/sum_test
print(w_regr_two)

w_regressor = inverse_regressor/sum_test
print(w_regressor)

w_regressor_two = inverse_regressor_two/sum_test
print(w_regressor_two)

w_rand = inverse_rand/sum_test
print(w_rand)


w_rand_two = inverse_rand_two/sum_test
print(w_rand_two)

w_neigh = inverse_neigh/sum_test
print(w_neigh)

w_neigh_two = inverse_neigh_two/sum_test
print(w_neigh_two)


weighted_average = w_linear * linr.predict(X_test) + w_regr * regr.predict(X_test) + w_regr_two * regr_two.predict(X_test) + w_regressor * regressor.predict(X_test) + w_regressor_two * regressor_two.predict(X_test)+ w_rand * rand.predict(X_test) + w_rand_two * rand_two.predict(X_test) + w_neigh * neigh.predict(X_test) + w_neigh_two * neigh_two.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, weighted_average))
# Out:
# 0.16578234416582338
# 0.10376573677231539
# 0.1281590776219351
# 0.10949617045510533
# 0.0883449522150499
# 0.12030599813159412
# 0.11379456140623287
# 0.08307990625560906
# 0.0872712529763348
# Mean squared error: 88.00

# %%
sum_train = inverse_linr_train + inverse_regr_train + inverse_regressor_train + inverse_rand_train + inverse_neigh_train
w_linear_train = inverse_linr_train/sum_train
print(w_linear_train)
w_regr_train = inverse_regr_train/sum_train
print(w_regr_train)
w_regressor_train = inverse_regressor_train/sum_train
print(w_regressor_train)
w_rand_train = inverse_rand_train/sum_train
print(w_rand_train)
w_neigh_train = inverse_neigh_train/sum_train
print(w_neigh_train)
weighted_average_train = w_linear_train * linr.predict(X_train) + w_regr_train * regr.predict(X_train) + w_regressor_train * regressor.predict(X_train) + w_rand_train * rand.predict(X_train) + w_neigh_train * neigh.predict(X_train)
print("Mean squared error: %.2f" % mean_squared_error(y_train, weighted_average_train))
# Out:
# 0.10944731729265991
# 0.06592272922301182
# 0.22503922210725008
# 0.40583917727717295
# 0.1937515540999052
# Mean squared error: 19.48

# %%
# buying one stock at a time - Linear Regression - $10,000
predictions = linr.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 27788.799917548575

# %%
# buying one stock at a time - Linear Regression - $1,000
predictions = linr.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 2443.128663148625

# %%
# buying one stock at a time - MLP Regression - $10,000
predictions = regr.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 25556.99372031655

# %%
# buying one stock at a time - MLP Regression Two - $10,000
predictions = regr_two.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 22060.539072653788

# %%
# buying one stock at a time - MLP Regression - $1,000
predictions = regr.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 1411.9521237714212

# %%
# buying one stock at a time - MLP Regression Two- $1,000
predictions = regr_two.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 1486.9958611038292

# %%
# buying one stock at a time - DecTree Regression - $10,000
predictions = regressor.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 23316.302168699433

# %%
# buying one stock at a time - DecTree Regression two- $10,000
predictions = regressor_two.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 26163.457042473183

# %%
# buying one stock at a time - DecTree Regression - $1,000
predictions = regressor.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 5647.770286010848

# %%
# buying one stock at a time - DecTree Regression two- $1,000
predictions = regressor_two.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 6834.555926329035

# %%
# buying one stock at a time - RandForest Regression - $10,000
predictions = rand.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 25096.33650634044

# %%
# buying one stock at a time - RandForest Regression two- $10,000
predictions = rand_two.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 22963.49493427234

# %%
# buying one stock at a time - RandForest Regression - $1,000
predictions = rand.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 6625.421621416925

# %%
# buying one stock at a time - RandForest Regression two- $1,000
predictions = rand_two.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 7172.698754653162

# %%
# buying one stock at a time - KNN Regression - $10,000
predictions = neigh.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 27649.3064707577

# %%
# buying one stock at a time - KNN Regression two - $10,000
predictions = neigh_two.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 26853.718648476184

# %%
# buying one stock at a time - KNN Regression - $1,000
predictions = neigh.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 4928.560114949615

# %%
# buying one stock at a time - KNN Regression two - $1,000
predictions = neigh_two.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 1
      amount -= Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 1:
      stocks -=1
      amount += Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 4871.321261558944

# %%
# buying 2 stocks at a time - Linear Regression - $10,000
predictions = linr.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 2
      amount -= 2 * Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 2:
      stocks -=2
      amount += 2 * Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 29820.488727121276

# %%
# buying 2 stocks at a time - Linear Regression - $1,000
predictions = linr.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 2
      amount -= 2 * Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 2:
      stocks -=2
      amount += 2 * Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 2819.1333997844495

# %%
# buying 2 stocks at a time - Multilayer Perceptron Regression - $10,000
predictions = regr.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 2
      amount -= 2 * Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 2:
      stocks -=2
      amount += 2 * Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 26591.041402975046

# %%
# buying 2 stocks at a time - Multilayer Perceptron Regression - $1,000
predictions = regr.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 2
      amount -= 2 * Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 2:
      stocks -=2
      amount += 2 * Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 1468.3504454343845

# %%
# buying 2 stocks at a time - Decision Tree Regression - $10,000
predictions = regressor.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 2
      amount -= 2 * Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 2:
      stocks -=2
      amount += 2 * Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 28298.004147748226

# %%
# buying 2 stocks at a time - Decision Tree Regression - $1,000
predictions = regressor.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 2
      amount -= 2 * Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 2:
      stocks -=2
      amount += 2 * Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 9028.853034895978

# %%
# buying 2 stocks at a time - Random Forest Regression - $10,000
predictions = rand.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 2
      amount -= 2 * Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 2:
      stocks -=2
      amount += 2 * Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 31080.490818410824

# %%
# buying 2 stocks at a time - Random Forest Regression - $1,000
predictions = rand.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 2
      amount -= 2 * Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 2:
      stocks -=2
      amount += 2 * Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 10969.81017171823

# %%
# buying 2 stocks at a time - KNN Regression - $10,000
predictions = neigh.predict(X)
stocks = 0
amount = 10000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 2
      amount -= 2 * Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 2:
      stocks -=2
      amount += 2 * Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 32155.365267506026

# %%
# buying 2 stocks at a time - KNN Regression - $1,000
predictions = neigh.predict(X)
stocks = 0
amount = 1000
for i in range(1200):
  if predictions[i+1] > Y[i]:
    if amount > Y[i]:
      stocks += 2
      amount -= 2 * Y[i]
  if predictions[i+1] < Y[i]:
    if stocks >= 2:
      stocks -=2
      amount += 2 * Y[i]
  if i == 1199:
    amount += Y[i] * stocks
    stocks -= stocks

print(amount)
# Out:
# 8320.176528980215
